# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

import pandas as pd
df  = pd.read_csv("data/data_prep.csv")
df.drop(columns=['student','lgain_pp', 'lgain_pe'], inplace=True)

df = df.apply(pd.to_numeric, errors='coerce')
# Remove rows with NaN values
df = df.dropna()

# Carga el conjunto de datos
X = df.drop(columns=['take_exam'])
y = df.take_exam

for size in [0.1, 0.2, 0.3]:
    for neigh in [3,4,5]:
        # Dividir los datos en conjuntos de entrenamiento y prueba
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=size, random_state=42)

        # Crear y ajustar el clasificador KNN con k=3
        knn = KNeighborsClassifier(n_neighbors=neigh)
        knn.fit(X_train, y_train)

        # Realizar predicciones en el conjunto de prueba
        y_pred = knn.predict(X_test)
        print("para size:", size)
        print("para vecinos: ", neigh)
        # Imprimir el informe de clasificación
        print(classification_report(y_test, y_pred))
# Out:
# para size: 0.1
# para vecinos:  3
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.69      0.72        13
#          1.0       0.92      0.94      0.93        51
#
#     accuracy                           0.89        64
#    macro avg       0.84      0.82      0.83        64
# weighted avg       0.89      0.89      0.89        64
#
# para size: 0.1
# para vecinos:  4
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.69      0.72        13
#          1.0       0.92      0.94      0.93        51
#
#     accuracy                           0.89        64
#    macro avg       0.84      0.82      0.83        64
# weighted avg       0.89      0.89      0.89        64
#
# para size: 0.1
# para vecinos:  5
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.62      0.73        13
#          1.0       0.91      0.98      0.94        51
#
#     accuracy                           0.91        64
#    macro avg       0.90      0.80      0.84        64
# weighted avg       0.90      0.91      0.90        64
#
# para size: 0.2
# para vecinos:  3
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.71      0.77        17
#          1.0       0.96      0.98      0.97       110
#
#     accuracy                           0.94       127
#    macro avg       0.91      0.84      0.87       127
# weighted avg       0.94      0.94      0.94       127
#
# para size: 0.2
# para vecinos:  4
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.71      0.75        17
#          1.0       0.96      0.97      0.96       110
#
#     accuracy                           0.94       127
#    macro avg       0.88      0.84      0.86       127
# weighted avg       0.93      0.94      0.94       127
#
# para size: 0.2
# para vecinos:  5
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.65      0.76        17
#          1.0       0.95      0.99      0.97       110
#
#     accuracy                           0.94       127
#    macro avg       0.93      0.82      0.86       127
# weighted avg       0.94      0.94      0.94       127
#
# para size: 0.3
# para vecinos:  3
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.78      0.84        27
#          1.0       0.96      0.99      0.98       163
#
#     accuracy                           0.96       190
#    macro avg       0.94      0.88      0.91       190
# weighted avg       0.96      0.96      0.96       190
#
# para size: 0.3
# para vecinos:  4
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.78      0.81        27
#          1.0       0.96      0.98      0.97       163
#
#     accuracy                           0.95       190
#    macro avg       0.90      0.88      0.89       190
# weighted avg       0.95      0.95      0.95       190
#
# para size: 0.3
# para vecinos:  5
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.74      0.83        27
#          1.0       0.96      0.99      0.98       163
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.87      0.90       190
# weighted avg       0.96      0.96      0.96       190
